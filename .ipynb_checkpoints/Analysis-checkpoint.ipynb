# %%
import pandas as pd
from datetime import date
from datetime import datetime
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#this is our google stock price dataset
df = pd.read_csv("google_stock_price.csv")
df_copy = df.copy()
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.611960  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.640104  184645512

# %%
#for this project we'll mainly be looking at the close column
#boxplot of the close column
sns.boxplot(df_copy['Close'])
# Out:
# <Axes: >

# %%
#statistics of our data
upper_quartile = np.percentile(df_copy['Close'], 75)
upper_quartile
lower_quartile = np.percentile(df_copy['Close'], 25)
iqr =  upper_quartile - lower_quartile
upper_whisker = df_copy[df_copy['Close'] <= upper_quartile + 1.5*iqr].max()
upper_whisker
# Out:
# Date         2023-10-27
# Open         127.574997
# High         129.550003
# Low          123.099998
# Close        123.870003
# Adj Close    123.870003
# Volume       1650832619
# dtype: object

# %%
#visualzing outliers and a method to show what it would look like without them
def removal_box_plot(df_copy, column, threshold):
    sns.boxplot(df_copy[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()
 
    removed_outliers = df_copy[df_copy[column] <= threshold]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers
 
 
threshold_value = 120
 
no_outliers = removal_box_plot(df_copy, 'Close', threshold_value)
count_row = df_copy.shape[0]
count_row
# Out:
# 4842

# %%
#method for removing outliers from our dataset
def remove_outliers(df_copy, outlier_margin = 0.67):
    Q1 = df_copy["Close"].quantile(0.15)
    Q3  = df_copy["Close"].quantile(0.85)
    IQR = Q3 - Q1
    print(Q1, Q3, IQR)
    print(Q1 - outlier_margin * IQR)
    print(Q3 + outlier_margin * IQR)
    return df_copy[(df_copy["Close"] > (Q1 - outlier_margin * IQR)) & (df_copy["Close"] < (Q3 + outlier_margin * IQR))]
df_copy2 = remove_outliers(df_copy)
count_row = df_copy2.shape[0]
print(df_copy.shape[0], df_copy2.shape[0])
# Out:
# 10.693430995941164 88.14062652587887 77.44719552993772
# -41.19619000911711
# 140.03024753093715
# 4842 4745

# %%
#creating a copy of our dataset (without outliers) so we can use it to train both models (LTSM, and RF)
df_copy2=df.copy()

# %%
df_copy['Date'] = pd.to_datetime(df_copy['Date'])
plt.figure(figsize=(12, 6))
plt.plot(df_copy['Date'], df_copy['Close'], label='Close Price', color='blue')

plt.title('Google Stock Price 4842 Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_copy['Date'], df_copy['Open'], label='Open Price', color='green')

plt.title('Google Stock Price 4842Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_copy['Date'], df_copy['High'], label='High Price', color='red')

plt.title('Google Stock Price 4842Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_copy['Date'], df_copy['Low'], label='Low Price', color='orange')

plt.title('Google Stock Price 4842Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.subplot(1, 1, 1)
sns.histplot(df_copy['Volume'], bins=30, kde=True, color='green')
plt.title('Google Stock Trading Volume Distribution')
plt.xlabel('Volume')
plt.ylabel('Frequency')

plt.tight_layout()

plt.show()
# Out:
# /usr/users/quota/students/2021/zsaleem/miniconda3/envs/csci373/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
google_close_iqr = df_copy['Close'].quantile(0.75) - df_copy['Close'].quantile(0.25)
google_close_upper_bound = df_copy['Close'].quantile(0.75) + 1.5 * google_close_iqr

# Identify outliers for Google stock
google_outliers = df_copy[df_copy['Close'] > google_close_upper_bound]

# Print or further analyze the identified outliers
print("Google Stock Outliers:")
print(google_outliers)
# Out:
# Google Stock Outliers:
#            Date        Open        High         Low       Close   Adj Close  \
# 4229 2021-06-08  123.995003  124.724747  123.412003  124.142502  124.142502
# 4230 2021-06-09  124.974998  125.250000  124.366501  124.570000  124.570000
# 4231 2021-06-10  124.700500  126.163002  124.699997  126.080002  126.080002
# 4232 2021-06-11  126.246002  126.349503  124.914497  125.696503  125.696503
# 4233 2021-06-14  125.669502  126.411499  125.046997  126.351997  126.351997
# ...         ...         ...         ...         ...         ...         ...
# 4837 2023-11-06  130.220001  131.559998  129.929993  131.449997  131.449997
# 4838 2023-11-07  131.979996  133.279999  131.139999  132.399994  132.399994
# 4839 2023-11-08  132.360001  133.539993  132.160004  133.259995  133.259995
# 4840 2023-11-09  133.360001  133.960007  131.509995  131.690002  131.690002
# 4841 2023-11-10  131.529999  134.270004  130.869995  134.059998  134.059998
#
#         Volume
# 4229  25060000
# 4230  20126000
# 4231  31234000
# 4232  25240000
# 4233  22550000
# ...        ...
# 4837  15360400
# 4838  19223800
# 4839  15093600
# 4840  17976500
# 4841  20872900
#
# [313 rows x 7 columns]

# %%
google_close_iqr = df_copy['Close'].quantile(0.75) - df_copy['Close'].quantile(0.25)
google_close_upper_bound = df_copy['Close'].quantile(0.75) + 1.5 * google_close_iqr

# Identify outliers for Google stock
google_outliers = df_copy[df_copy['Close'] > google_close_upper_bound]

plt.figure(figsize=(8, 4))

plt.hist(df_copy['Close'], bins=30, color='green', alpha=0.7, label='All Data')
plt.hist(google_outliers['Close'], bins=10, color='red', alpha=0.5, label='Outliers')
plt.title('Google Stock Trading Volume Distribution with Outliers')
plt.xlabel('Close')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Select relevant columns and set 'Date' as the index
google_data = df_copy[['Date', 'Close']]
google_data.set_index('Date', inplace=True)

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(google_data.values)

# Prepare the data for LSTM
def create_dataset(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps, 0])
        y.append(data[i + time_steps, 0])
    return np.array(X), np.array(y)

time_steps = 10  # Adjust as needed
X, y = create_dataset(scaled_data, time_steps)

# Split the data into training and testing sets
train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# Reshape the input data for LSTM
trainX = np.expand_dims(trainX, axis=1)
testX = np.expand_dims(testX, axis=1)

# Build the LSTM model
model = Sequential([
    LSTM(50, activation='relu', input_shape=(1, time_steps)),
    Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(trainX, trainY, epochs=100, batch_size=32, verbose=2)

# Make predictions on the test set
predictions = model.predict(testX)
predictions = scaler.inverse_transform(predictions)

# Invert the scaling for the actual values
actual_values = scaler.inverse_transform(testY.reshape(-1, 1))

# Evaluate the model
mse = mean_squared_error(actual_values, predictions)
print(f'Mean Squared Error: {mse}')

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(google_data.index[train_size + time_steps:], actual_values, label='Actual Prices')
plt.plot(google_data.index[train_size + time_steps:], predictions, label='LSTM Predictions', color='red')
plt.title('LSTM Model for Google Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/100
# 121/121 - 1s - loss: 0.0046 - 807ms/epoch - 7ms/step
# Epoch 2/100
# 121/121 - 0s - loss: 3.3566e-05 - 450ms/epoch - 4ms/step
# Epoch 3/100
# 121/121 - 0s - loss: 2.9728e-05 - 308ms/epoch - 3ms/step
# Epoch 4/100
# 121/121 - 0s - loss: 2.9475e-05 - 347ms/epoch - 3ms/step
# Epoch 5/100
# 121/121 - 0s - loss: 2.9436e-05 - 284ms/epoch - 2ms/step
# Epoch 6/100
# 121/121 - 0s - loss: 2.9115e-05 - 412ms/epoch - 3ms/step
# Epoch 7/100
# 121/121 - 0s - loss: 2.8807e-05 - 397ms/epoch - 3ms/step
# Epoch 8/100
# 121/121 - 0s - loss: 2.8736e-05 - 409ms/epoch - 3ms/step
# Epoch 9/100
# 121/121 - 0s - loss: 2.8172e-05 - 343ms/epoch - 3ms/step
# Epoch 10/100
# 121/121 - 0s - loss: 2.7617e-05 - 359ms/epoch - 3ms/step
# Epoch 11/100
# 121/121 - 0s - loss: 2.7701e-05 - 393ms/epoch - 3ms/step
# Epoch 12/100
# 121/121 - 0s - loss: 2.7506e-05 - 369ms/epoch - 3ms/step
# Epoch 13/100
# 121/121 - 0s - loss: 2.7049e-05 - 329ms/epoch - 3ms/step
# Epoch 14/100
# 121/121 - 0s - loss: 2.6642e-05 - 342ms/epoch - 3ms/step
# Epoch 15/100
# 121/121 - 0s - loss: 2.5454e-05 - 397ms/epoch - 3ms/step
# Epoch 16/100
# 121/121 - 0s - loss: 2.5021e-05 - 368ms/epoch - 3ms/step
# Epoch 17/100
# 121/121 - 0s - loss: 2.4321e-05 - 421ms/epoch - 3ms/step
# Epoch 18/100
# 121/121 - 0s - loss: 2.3596e-05 - 392ms/epoch - 3ms/step
# Epoch 19/100
# 121/121 - 0s - loss: 2.2910e-05 - 424ms/epoch - 4ms/step
# Epoch 20/100
# 121/121 - 0s - loss: 2.3462e-05 - 372ms/epoch - 3ms/step
# Epoch 21/100
# 121/121 - 0s - loss: 2.2081e-05 - 389ms/epoch - 3ms/step
# Epoch 22/100
# 121/121 - 0s - loss: 2.1439e-05 - 436ms/epoch - 4ms/step
# Epoch 23/100
# 121/121 - 0s - loss: 2.1756e-05 - 446ms/epoch - 4ms/step
# Epoch 24/100
# 121/121 - 0s - loss: 2.1390e-05 - 331ms/epoch - 3ms/step
# Epoch 25/100
# 121/121 - 0s - loss: 2.0090e-05 - 311ms/epoch - 3ms/step
# Epoch 26/100
# 121/121 - 0s - loss: 1.9294e-05 - 364ms/epoch - 3ms/step
# Epoch 27/100
# 121/121 - 0s - loss: 1.9032e-05 - 340ms/epoch - 3ms/step
# Epoch 28/100
# 121/121 - 0s - loss: 1.8900e-05 - 369ms/epoch - 3ms/step
# Epoch 29/100
# 121/121 - 0s - loss: 1.9555e-05 - 399ms/epoch - 3ms/step
# Epoch 30/100
# 121/121 - 0s - loss: 1.7530e-05 - 464ms/epoch - 4ms/step
# Epoch 31/100
# 121/121 - 0s - loss: 1.7264e-05 - 448ms/epoch - 4ms/step
# Epoch 32/100
# 121/121 - 0s - loss: 1.7431e-05 - 362ms/epoch - 3ms/step
# Epoch 33/100
# 121/121 - 0s - loss: 1.6652e-05 - 370ms/epoch - 3ms/step
# Epoch 34/100
# 121/121 - 0s - loss: 1.6607e-05 - 321ms/epoch - 3ms/step
# Epoch 35/100
# 121/121 - 0s - loss: 1.6155e-05 - 390ms/epoch - 3ms/step
# Epoch 36/100
# 121/121 - 0s - loss: 1.5931e-05 - 334ms/epoch - 3ms/step
# Epoch 37/100
# 121/121 - 0s - loss: 1.7532e-05 - 448ms/epoch - 4ms/step
# Epoch 38/100
# 121/121 - 0s - loss: 1.6393e-05 - 381ms/epoch - 3ms/step
# Epoch 39/100
# 121/121 - 0s - loss: 1.5870e-05 - 389ms/epoch - 3ms/step
# Epoch 40/100
# 121/121 - 0s - loss: 1.5144e-05 - 410ms/epoch - 3ms/step
# Epoch 41/100
# 121/121 - 0s - loss: 1.5164e-05 - 437ms/epoch - 4ms/step
# Epoch 42/100
# 121/121 - 0s - loss: 1.6802e-05 - 399ms/epoch - 3ms/step
# Epoch 43/100
# 121/121 - 0s - loss: 1.6500e-05 - 431ms/epoch - 4ms/step
# Epoch 44/100
# 121/121 - 0s - loss: 1.5931e-05 - 419ms/epoch - 3ms/step
# Epoch 45/100
# 121/121 - 0s - loss: 1.5355e-05 - 413ms/epoch - 3ms/step
# Epoch 46/100
# 121/121 - 0s - loss: 1.4967e-05 - 393ms/epoch - 3ms/step
# Epoch 47/100
# 121/121 - 0s - loss: 1.4577e-05 - 368ms/epoch - 3ms/step
# Epoch 48/100
# 121/121 - 0s - loss: 1.4099e-05 - 436ms/epoch - 4ms/step
# Epoch 49/100
# 121/121 - 0s - loss: 1.5276e-05 - 410ms/epoch - 3ms/step
# Epoch 50/100
# 121/121 - 0s - loss: 1.4576e-05 - 389ms/epoch - 3ms/step
# Epoch 51/100
# 121/121 - 0s - loss: 1.4947e-05 - 450ms/epoch - 4ms/step
# Epoch 52/100
# 121/121 - 0s - loss: 1.5285e-05 - 331ms/epoch - 3ms/step
# Epoch 53/100
# 121/121 - 0s - loss: 1.4056e-05 - 388ms/epoch - 3ms/step
# Epoch 54/100
# 121/121 - 0s - loss: 1.4755e-05 - 369ms/epoch - 3ms/step
# Epoch 55/100
# 121/121 - 0s - loss: 1.5442e-05 - 413ms/epoch - 3ms/step
# Epoch 56/100
# 121/121 - 0s - loss: 1.5127e-05 - 443ms/epoch - 4ms/step
# Epoch 57/100
# 121/121 - 0s - loss: 1.4567e-05 - 405ms/epoch - 3ms/step
# Epoch 58/100
# 121/121 - 0s - loss: 1.4251e-05 - 396ms/epoch - 3ms/step
# Epoch 59/100
# 121/121 - 0s - loss: 1.5079e-05 - 452ms/epoch - 4ms/step
# Epoch 60/100
# 121/121 - 0s - loss: 1.2927e-05 - 333ms/epoch - 3ms/step
# Epoch 61/100
# 121/121 - 0s - loss: 1.4449e-05 - 355ms/epoch - 3ms/step
# Epoch 62/100
# 121/121 - 0s - loss: 1.4885e-05 - 281ms/epoch - 2ms/step
# Epoch 63/100
# 121/121 - 0s - loss: 1.4025e-05 - 423ms/epoch - 3ms/step
# Epoch 64/100
# 121/121 - 0s - loss: 1.3395e-05 - 446ms/epoch - 4ms/step
# Epoch 65/100
# 121/121 - 0s - loss: 1.4664e-05 - 359ms/epoch - 3ms/step
# Epoch 66/100
# 121/121 - 0s - loss: 1.3334e-05 - 328ms/epoch - 3ms/step
# Epoch 67/100
# 121/121 - 0s - loss: 1.4505e-05 - 327ms/epoch - 3ms/step
# Epoch 68/100
# 121/121 - 0s - loss: 1.3601e-05 - 268ms/epoch - 2ms/step
# Epoch 69/100
# 121/121 - 0s - loss: 1.3338e-05 - 319ms/epoch - 3ms/step
# Epoch 70/100
# 121/121 - 0s - loss: 1.3617e-05 - 426ms/epoch - 4ms/step
# Epoch 71/100
# 121/121 - 0s - loss: 1.3439e-05 - 323ms/epoch - 3ms/step
# Epoch 72/100
# 121/121 - 0s - loss: 1.4238e-05 - 316ms/epoch - 3ms/step
# Epoch 73/100
# 121/121 - 0s - loss: 1.2587e-05 - 433ms/epoch - 4ms/step
# Epoch 74/100
# 121/121 - 0s - loss: 1.2839e-05 - 407ms/epoch - 3ms/step
# Epoch 75/100
# 121/121 - 0s - loss: 1.4054e-05 - 391ms/epoch - 3ms/step
# Epoch 76/100
# 121/121 - 0s - loss: 1.2874e-05 - 438ms/epoch - 4ms/step
# Epoch 77/100
# 121/121 - 0s - loss: 1.3722e-05 - 476ms/epoch - 4ms/step
# Epoch 78/100
# 121/121 - 0s - loss: 1.3372e-05 - 482ms/epoch - 4ms/step
# Epoch 79/100
# 121/121 - 0s - loss: 1.3895e-05 - 468ms/epoch - 4ms/step
# Epoch 80/100
# 121/121 - 0s - loss: 1.3561e-05 - 425ms/epoch - 4ms/step
# Epoch 81/100
# 121/121 - 0s - loss: 1.3416e-05 - 454ms/epoch - 4ms/step
# Epoch 82/100
# 121/121 - 0s - loss: 1.4115e-05 - 443ms/epoch - 4ms/step
# Epoch 83/100
# 121/121 - 0s - loss: 1.3684e-05 - 230ms/epoch - 2ms/step
# Epoch 84/100
# 121/121 - 0s - loss: 1.2240e-05 - 426ms/epoch - 4ms/step
# Epoch 85/100
# 121/121 - 0s - loss: 1.3084e-05 - 248ms/epoch - 2ms/step
# Epoch 86/100
# 121/121 - 0s - loss: 1.2711e-05 - 351ms/epoch - 3ms/step
# Epoch 87/100
# 121/121 - 0s - loss: 1.3636e-05 - 461ms/epoch - 4ms/step
# Epoch 88/100
# 121/121 - 1s - loss: 1.4318e-05 - 500ms/epoch - 4ms/step
# Epoch 89/100
# 121/121 - 0s - loss: 1.2875e-05 - 436ms/epoch - 4ms/step
# Epoch 90/100
# 121/121 - 0s - loss: 1.4158e-05 - 477ms/epoch - 4ms/step
# Epoch 91/100
# 121/121 - 0s - loss: 1.3362e-05 - 460ms/epoch - 4ms/step
# Epoch 92/100
# 121/121 - 0s - loss: 1.2632e-05 - 462ms/epoch - 4ms/step
# Epoch 93/100
# 121/121 - 0s - loss: 1.1923e-05 - 454ms/epoch - 4ms/step
# Epoch 94/100
# 121/121 - 0s - loss: 1.2071e-05 - 461ms/epoch - 4ms/step
# Epoch 95/100
# 121/121 - 0s - loss: 1.3924e-05 - 470ms/epoch - 4ms/step
# Epoch 96/100
# 121/121 - 0s - loss: 1.3048e-05 - 426ms/epoch - 4ms/step
# Epoch 97/100
# 121/121 - 0s - loss: 1.2995e-05 - 405ms/epoch - 3ms/step
# Epoch 98/100
# 121/121 - 0s - loss: 1.2545e-05 - 498ms/epoch - 4ms/step
# Epoch 99/100
# 121/121 - 0s - loss: 1.3099e-05 - 441ms/epoch - 4ms/step
# Epoch 100/100
# 121/121 - 0s - loss: 1.2517e-05 - 486ms/epoch - 4ms/step
# 31/31 [==============================] - 0s 662us/step
# Mean Squared Error: 17.397280526786485

# %%
#Model 2: Random Forest Classification

data = df_copy2

data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2004-08-19  2.490664  2.591785  2.390042  2.499133   2.499133  897427216
# 1  2004-08-20  2.515820  2.716817  2.503118  2.697639   2.697639  458857488
# 2  2004-08-23  2.758411  2.826406  2.716070  2.724787   2.724787  366857939
# 3  2004-08-24  2.770615  2.779581  2.579581  2.611960   2.611960  306396159
# 4  2004-08-25  2.614201  2.689918  2.587302  2.640104   2.640104  184645512

# %%
# Adding additional columns

data['Open-Close'] = (data.Open - data.Close)/data.Open
data['High-Low'] = (data.High - data.Low)/data.Low
data['percent_change'] = data['Adj Close'].pct_change()
data['std_5'] = data['percent_change'].rolling(5).std()
data['ret_5'] = data['percent_change'].rolling(5).mean()
data.dropna(inplace=True)

# X is the input variable
X = data[['Open-Close', 'High-Low', 'std_5', 'ret_5']]

# Y is the target or output variable
y = np.where(data['Adj Close'].shift(-1) > data['Adj Close'], 1, -1)

# %%
dataset_length = data.shape[0]

split = int(dataset_length * 0.75)
split
# Out:
# 3627

# %%
# Splitiing the X and y into train and test datasets
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Print the size of the train and test dataset
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (3627, 4) (1210, 4)
# (3627,) (1210,)

# %%
#training the model and getting predictions
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
model = clf.fit(X_train, y_train)
from sklearn.metrics import accuracy_score
print('Correct Prediction (%): ', accuracy_score(y_test, model.predict(X_test), normalize=True)*100.0)

# Run the code to view the classification report metrics
from sklearn.metrics import classification_report
y_pred_test=model.predict(X_test)
report = classification_report(y_test, model.predict(X_test))
print(report)
# Out:
# Correct Prediction (%):  50.082644628099175
#               precision    recall  f1-score   support
#
#           -1       0.46      0.45      0.45       558
#            1       0.54      0.54      0.54       652
#
#     accuracy                           0.50      1210
#    macro avg       0.50      0.50      0.50      1210
# weighted avg       0.50      0.50      0.50      1210

# %%
#Plot strategy returns
data['strategy_returns'] = data.percent_change.shift(-1) * model.predict(X)
# %matplotlib inline
import matplotlib.pyplot as plt
data.strategy_returns[split:].hist()
plt.xlabel('Strategy returns (%)')

plt.show()

# %%
(data.strategy_returns[split:]+1).cumprod().plot()
plt.ylabel('Strategy returns (%)')
plt.xlabel('time')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[252, 306],
#        [298, 354]])

# %%
# Get and reshape confusion matrix data\
matrix = confusion_matrix(y_test, y_pred_test)
matrix = matrix.astype('float') / matrix.sum(axis=1)[:, np.newaxis]

# Build the plot
plt.figure(figsize=(16,7))
sns.set(font_scale=1.4)
sns.heatmap(matrix, annot=True, annot_kws={'size':10},
            cmap=plt.cm.Greens, linewidths=0.2)

# Add labels to the plot
class_names = ['buy', 'sell']
tick_marks = np.arange(len(class_names))
tick_marks2 = tick_marks + 0.5
plt.xticks(tick_marks, class_names, rotation=25)
plt.yticks(tick_marks2, class_names, rotation=0)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix for Random Forest Model')
plt.show()
